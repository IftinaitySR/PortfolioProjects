# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd

# This allows to se all columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# This normalizes the data and makes it all pretty in a dataframe

df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#        id          name symbol          slug  infinite_supply  \
# 0       1       Bitcoin    BTC       bitcoin            False
# 1    1027      Ethereum    ETH      ethereum             True
# 2     825   Tether USDt   USDT        tether             True
# 3    1839           BNB    BNB           bnb            False
# 4    3408          USDC   USDC      usd-coin            False
# 5      52           XRP    XRP           xrp            False
# 6    5426        Solana    SOL        solana             True
# 7    1958          TRON    TRX          tron             True
# 8   32196   Hyperliquid   HYPE   hyperliquid            False
# 9      74      Dogecoin   DOGE      dogecoin             True
# 10   3957  UNUS SED LEO    LEO  unus-sed-leo            False
# 11   1437         Zcash    ZEC         zcash            False
# 12    512       Stellar    XLM       stellar            False
# 13   2010       Cardano    ADA       cardano            False
# 14    328        Monero    XMR        monero             True
#
#     circulating_supply  total_supply    max_supply                date_added  \
# 0         2.005273e+07  2.005273e+07  2.100000e+07  2010-07-13T00:00:00.000Z
# 1         1.206832e+08  1.206832e+08           NaN  2015-08-07T00:00:00.000Z
# 2         1.843345e+11  1.931271e+11           NaN  2015-02-25T00:00:00.000Z
# 3         1.347824e+08  1.347824e+08  1.347824e+08  2017-07-25T00:00:00.000Z
# 4         7.288183e+10  7.288183e+10           NaN  2018-10-08T00:00:00.000Z
# 5         6.224151e+10  9.998565e+10  1.000000e+11  2013-08-04T00:00:00.000Z
# 6         5.811295e+08  6.297179e+08           NaN  2020-04-10T00:00:00.000Z
# 7         9.485778e+10  9.485776e+10           NaN  2017-09-13T00:00:00.000Z
# 8         2.527677e+08  9.534681e+08  9.534684e+08  2024-07-15T10:14:50.000Z
# 9         1.706655e+11  1.706655e+11           NaN  2013-12-15T00:00:00.000Z
# 10        9.202684e+08  9.852395e+08           NaN  2019-05-21T00:00:00.000Z
# 11        1.675807e+07  1.675800e+07  2.100000e+07  2016-10-29T00:00:00.000Z
# 12        3.401071e+10  5.000179e+10  5.000181e+10  2014-08-05T00:00:00.000Z
# 13        3.645332e+10  4.499232e+10  4.500000e+10  2017-10-01T00:00:00.000Z
# 14        1.877423e+07  1.877423e+07           NaN  2014-05-21T00:00:00.000Z
#
#     num_market_pairs  cmc_rank              last_updated tvl_ratio  platform  \
# 0              12666         1  2026-07-06T06:20:00.000Z      None       NaN
# 1              12125         2  2026-07-06T06:19:00.000Z      None       NaN
# 2             188674         3  2026-07-06T06:20:00.000Z      None       NaN
# 3               3293         4  2026-07-06T06:20:00.000Z      None       NaN
# 4              41268         5  2026-07-06T06:20:00.000Z      None       NaN
# 5               1846         6  2026-07-06T06:20:00.000Z      None       NaN
# 6               1142         7  2026-07-06T06:19:00.000Z      None       NaN
# 7               1349         8  2026-07-06T06:20:00.000Z      None       NaN
# 8                285         9  2026-07-06T06:20:00.000Z      None       NaN
# 9               1451        10  2026-07-06T06:19:00.000Z      None       NaN
# 10                69        11  2026-07-06T06:19:00.000Z      None       NaN
# 11               627        12  2026-07-06T06:20:00.000Z      None       NaN
# 12               825        13  2026-07-06T06:19:00.000Z      None       NaN
# 13              1716        14  2026-07-06T06:20:00.000Z      None       NaN
# 14               370        15  2026-07-06T06:20:00.000Z      None       NaN
#
#     self_reported_circulating_supply  self_reported_market_cap  \
# 0                                NaN                       NaN
# 1                                NaN                       NaN
# 2                                NaN                       NaN
# 3                                NaN                       NaN
# 4                       6.090122e+10              6.089018e+10
# 5                                NaN                       NaN
# 6                       5.252369e+08              4.219193e+10
# 7                       9.466789e+10              3.115143e+10
# 8                       3.339317e+08              2.364086e+10
# 9                                NaN                       NaN
# 10                               NaN                       NaN
# 11                               NaN                       NaN
# 12                      3.153141e+10              6.283283e+09
# 13                      3.799790e+10              7.008354e+09
# 14                               NaN                       NaN
#
#     minted_market_cap                                               tags  \
# 0        1.263429e+12  [mineable, pow, sha-256, store-of-value, state...
# 1        2.136371e+11  [pos, smart-contracts, ethereum-ecosystem, coi...
# 2        1.929349e+11  [stablecoin, asset-backed-stablecoin, usd-stab...
# 3        7.843808e+10  [marketplace, centralized-exchange, payments, ...
# 4        7.286862e+10  [medium-of-exchange, stablecoin, asset-backed-...
# 5        1.137822e+11  [medium-of-exchange, enterprise-solutions, xrp...
# 6        5.058482e+10  [pos, platform, solana-ecosystem, cms-holdings...
# 7        3.121391e+10  [media, payments, tron-ecosystem, layer-1, dwf...
# 8        6.750126e+10  [decentralized-exchange-dex-token, defi, deriv...
# 9        1.306862e+10  [mineable, pow, scrypt, medium-of-exchange, me...
# 10       9.222338e+09  [marketplace, centralized-exchange, discount-t...
# 11       7.635316e+09  [mineable, pow, equihash, medium-of-exchange, ...
# 12       9.963886e+09  [medium-of-exchange, enterprise-solutions, dec...
# 13       8.298408e+09  [dpos, pos, platform, research, smart-contract...
# 14       6.002376e+09  [mineable, pow, medium-of-exchange, privacy, r...
#
#     quote.USD.price  quote.USD.volume_24h  quote.USD.cex_volume_24h  \
# 0      63005.322245          1.986269e+10              1.984985e+10
# 1       1770.230377          1.108210e+10              1.100932e+10
# 2          0.999005          4.862452e+10              4.735717e+10
# 3        581.960691          1.369782e+09              1.347634e+09
# 4          0.999819          5.787137e+09              4.595458e+09
# 5          1.137985          1.220663e+09              1.219619e+09
# 6         80.329333          1.783616e+09              1.783597e+09
# 7          0.329060          5.727180e+08              5.726618e+08
# 8         70.795505          3.446713e+08              2.872639e+08
# 9          0.076574          5.514903e+08              5.511001e+08
# 10         9.360504          5.873143e+05              5.873143e+05
# 11       455.622245          2.990530e+08              2.934593e+08
# 12         0.199271          2.471215e+08              2.470199e+08
# 13         0.184441          5.017235e+08              5.010723e+08
# 14       319.713531          1.023515e+08              1.023515e+08
#
#     quote.USD.dex_volume_24h  quote.USD.volume_change_24h  \
# 0               1.283447e+07                      11.8235
# 1               7.277783e+07                      25.3241
# 2               1.267355e+09                       6.5909
# 3               2.214742e+07                      24.9926
# 4               1.191679e+09                      15.2650
# 5               1.044568e+06                     -31.4448
# 6               1.848824e+04                      -7.3180
# 7               5.611690e+04                      42.7338
# 8               5.740744e+07                      13.9188
# 9               3.901676e+05                     -14.0920
# 10              0.000000e+00                     133.5821
# 11              5.593675e+06                     -12.8830
# 12              1.016685e+05                     -63.9697
# 13              6.512783e+05                     -41.6942
# 14              0.000000e+00                      -4.0984
#
#     quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# 0                     -0.200933                      0.477696
# 1                     -0.223336                      0.456486
# 2                      0.008388                     -0.014104
# 3                     -0.323275                      1.938933
# 4                      0.019392                     -0.012045
# 5                     -0.408223                      0.253081
# 6                     -0.250761                     -0.038675
# 7                      0.093327                      1.366943
# 8                     -1.024884                      3.347569
# 9                     -0.416052                      1.147392
# 10                     0.001934                      2.181866
# 11                     0.276949                      0.043174
# 12                    -0.210895                     -0.285117
# 13                    -0.867349                     -2.442767
# 14                    -0.488135                     -3.623265
#
#     quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# 0                      4.651096                      3.111790
# 1                     11.668762                     12.624614
# 2                      0.059111                     -0.054929
# 3                      5.044181                      0.925842
# 4                      0.010416                      0.013180
# 5                      8.170564                      3.906520
# 6                     10.796363                     27.800636
# 7                      2.007076                      2.572245
# 8                     12.322881                     19.206750
# 9                      4.559495                     -5.299108
# 10                    -0.585275                     -2.738422
# 11                    18.497171                     20.965846
# 12                    14.323061                      2.111184
# 13                    26.388391                     19.049712
# 14                     3.187269                      2.988044
#
#     quote.USD.percent_change_60d  quote.USD.percent_change_90d  \
# 0                     -22.161064                     -7.983856
# 1                     -23.736555                    -15.694207
# 2                      -0.077974                     -0.082394
# 3                      -9.773011                     -2.561635
# 4                       0.001185                      0.000657
# 5                     -19.130255                    -13.089821
# 6                      -9.018130                      1.211634
# 7                      -4.531447                      4.098397
# 8                      65.026898                     95.755510
# 9                     -30.779712                    -15.242401
# 10                     -9.536527                     -7.535605
# 11                    -15.441717                     73.898700
# 12                     24.185645                     28.455332
# 13                    -30.352899                    -24.012067
# 14                    -22.202696                     -2.184084
#
#     quote.USD.market_cap  quote.USD.market_cap_dominance  \
# 0           1.263429e+12                         57.9429
# 1           2.136371e+11                          9.7994
# 2           1.841511e+11                          8.4455
# 3           7.843808e+10                          3.5979
# 4           7.286862e+10                          3.3419
# 5           7.082991e+10                          3.2495
# 6           4.668175e+10                          2.1409
# 7           3.121392e+10                          1.4315
# 8           1.789482e+10                          0.8210
# 9           1.306862e+10                          0.5993
# 10          8.614176e+09                          0.3951
# 11          7.635348e+09                          0.3502
# 12          6.777336e+09                          0.3109
# 13          6.723470e+09                          0.3083
# 14          6.002376e+09                          0.2753
#
#     quote.USD.fully_diluted_market_cap quote.USD.tvl  \
# 0                         1.323112e+12          None
# 1                         2.136371e+11          None
# 2                         1.929349e+11          None
# 3                         7.843808e+10          None
# 4                         7.286862e+10          None
# 5                         1.137985e+11          None
# 6                         5.058482e+10          None
# 7                         3.121391e+10          None
# 8                         6.750128e+10          None
# 9                         1.306862e+10          None
# 10                        9.222338e+09          None
# 11                        9.568067e+09          None
# 12                        9.963890e+09          None
# 13                        8.299824e+09          None
# 14                        6.002376e+09          None
#
#       quote.USD.last_updated  platform.id platform.slug platform.name  \
# 0   2026-07-06T06:20:00.000Z          NaN           NaN           NaN
# 1   2026-07-06T06:19:00.000Z          NaN           NaN           NaN
# 2   2026-07-06T06:20:00.000Z       1027.0      ethereum      Ethereum
# 3   2026-07-06T06:20:00.000Z          NaN           NaN           NaN
# 4   2026-07-06T06:20:00.000Z       1027.0      ethereum      Ethereum
# 5   2026-07-06T06:20:00.000Z          NaN           NaN           NaN
# 6   2026-07-06T06:19:00.000Z          NaN           NaN           NaN
# 7   2026-07-06T06:20:00.000Z          NaN           NaN           NaN
# 8   2026-07-06T06:20:00.000Z      32196.0   hyperliquid   Hyperliquid
# 9   2026-07-06T06:19:00.000Z          NaN           NaN           NaN
# 10  2026-07-06T06:19:00.000Z       1027.0      ethereum      Ethereum
# 11  2026-07-06T06:20:00.000Z          NaN           NaN           NaN
# 12  2026-07-06T06:19:00.000Z          NaN           NaN           NaN
# 13  2026-07-06T06:20:00.000Z          NaN           NaN           NaN
# 14  2026-07-06T06:20:00.000Z          NaN           NaN           NaN
#
#    platform.symbol                      platform.token_address  \
# 0              NaN                                         NaN
# 1              NaN                                         NaN
# 2              ETH  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN                                         NaN
# 4              ETH  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 5              NaN                                         NaN
# 6              NaN                                         NaN
# 7              NaN                                         NaN
# 8             HYPE          0x0d01dc56dcaaca66ad901c959b4011ec
# 9              NaN                                         NaN
# 10             ETH  0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3
# 11             NaN                                         NaN
# 12             NaN                                         NaN
# 13             NaN                                         NaN
# 14             NaN                                         NaN
#
#                     timestamp
# 0  2026-07-06 13:22:21.176074
# 1  2026-07-06 13:22:21.176074
# 2  2026-07-06 13:22:21.176074
# 3  2026-07-06 13:22:21.176074
# 4  2026-07-06 13:22:21.176074
# 5  2026-07-06 13:22:21.176074
# 6  2026-07-06 13:22:21.176074
# 7  2026-07-06 13:22:21.176074
# 8  2026-07-06 13:22:21.176074
# 9  2026-07-06 13:22:21.176074
# 10 2026-07-06 13:22:21.176074
# 11 2026-07-06 13:22:21.176074
# 12 2026-07-06 13:22:21.176074
# 13 2026-07-06 13:22:21.176074
# 14 2026-07-06 13:22:21.176074

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    
    # Use this to keep it in a dataframe
    df2 = pd.json_normalize(data['data'])
    df2['Timestamp'] = pd.to_datetime('now')
    df = df.append(df2)

    # Use this to create a csv and append data to it
    df = pd.json_normalize(data['data'])
    df['timestamp'] = pd.to_datetime('now')
    df

    if not os.path.isfile(r'C:\Users\asus\OneDrive\Documents\Python Script\API.csv'): 
        df.to_csv(r'C:\Users\asus\OneDrive\Documents\Python Script\API.csv', header='column_names')
    else:
        df.to_csv(r'C:\Users\asus\OneDrive\Documents\Python Script\API.csv', mode='a', header=False)
        
    # Then to read in the file: 
    # df = pd.read_csv(r'C:\Users\asus\OneDrive\Documents\Python Script\API.csv')

# %%
import os 
import pandas as pd  # Added pandas import since we're working with DataFrames
from time import time
from time import sleep

def api_runner():
    # Example of how to fix DataFrame append operations inside this function
    # Replace any code that looks like this:
    # df = df.append(new_data)
    
    # With this:
    # df = pd.concat([df, new_data], ignore_index=True)
    
    # If you have multiple DataFrames to combine:
    # df = pd.concat([df1, df2, df3], ignore_index=True)
    
    pass  # Replace this with your actual API runner logic

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60) #sleep for 1 minute
exit()
# Out:
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed

# %%
df72 = pd.read_csv(r'C:\Users\asus\OneDrive\Documents\Python Script\API.csv')
df72

# %%
df

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df

# %%
# Coin trends over time

df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3

# %%
df4 = df3.stack()
df4

# %%
type(df4)

# %%
df5 = df4.to_frame(name='values')
df5

# %%
df5.count()

# %%
index = pd.Index(range(90))

df6 = df5.set_index(index)
df6

# %%
# Change the column name

df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
